# %% [markdown]
# # Análisis Preliminar de Datasets Diabetic_data.csv

# %% [markdown]
# ## - **Primera opción:** diabetic_data.csv

# %% [markdown]
# ##  - **Revisar su estructura y clasificar las variables**
#
# ### Cualitativas:
# * **encounter_id:** Código de identificación según llegada del paciente.
# * **patient_nbr:** Código de cama odontológica del paciente.
# * **race:** raza del paciente.
# * **gender:** genero del paciente.
# * **discharge_disposition_id:** código de tipo frecuencia de secreción.
# * **admission_source_id:** código,  tipo de precedencia del paciente;
#                 1	Discharged to home
#                 2   Discharged/transferred to another short term hospital
#                 3	Discharged/transferred to SNF
#                 4	Discharged/transferred to ICF
#                 5	Discharged/transferred to another type of inpatient care institution
#                 6	Discharged/transferred to home with home health service
#                 7	Left AMA
#                 8	Discharged/transferred to home under care of Home IV provider
#                 9	Admitted as an inpatient to this hospital
#                 10	Neonate discharged to another hospital for neonatal aftercare
#                 11	Expired
#                 12	Still patient or expected to return for outpatient services
#                 13	Hospice / home
#                 14	Hospice / medical facility
#                 15	Discharged/transferred within this institution to Medicare approved swing bed
#                 16	Discharged/transferred/referred another institution for outpatient services
#                 17	Discharged/transferred/referred to this institution for outpatient services
#                 18	NULL
#                 19	Expired at home. Medicaid only, hospice.
#                 20	Expired in a medical facility. Medicaid only, hospice.
#                 21	Expired, place unknown. Medicaid only, hospice.
#                 22	Discharged/transferred to another rehab fac including rehab units of a hospital.
#                 23	Discharged/transferred to a long term care hospital.
#                 24	Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.
#                 25	Not Mapped
#                 26	Unknown/Invalid
#                 30	Discharged/transferred to another Type of Health Care Institution not defined Elsewhere
#                 27	Discharged/transferred to a federal health care facility.
#                 28	Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital
#                 29	Discharged/transferred to a Critical Access Hospital (CAH).
#
# * **payer_code:** código de pago del paciente.
# * **medical_specialty:** Especialidad médica que el paciente requirió.
# * **max_glu_serum:** docis maxima de gluten que el paciente puede ingerir.
# * **insulin:** estabilidad de los niveles de insulina.
# * **glyburide-metformin:** Uso o no uso de este tipo de medicamento.
# * **glipizide-metformin:** Uso o no uno de este tipo de medicamento.
# * **change:** Cambios en el uso de medicamento.
# * **diabetesMed:** uso de medicina para la diabetes.
#
#
# ### Cuantitativas:
# * **age:** rango de edad del paciente.
# * **weight:** peso del paciente.
# * **admission_type_id:** Sala a la que ingreso el paciente;
#             (1)Emergency
#             (2)Urgent
#             (3)Elective
#             (4)Newborn
#             (5)Not Available
#             (6)NULL
#             (7)Trauma Center
#             (8)Not Mapped.
# * **time_in_hospital:** días de permanencia en el hospital.
# * **num_lab_procedures:** cantidad de laboratorios realizados.
# * **num_procedures:** cantidad de procedimientos quirurgicos.
# * **num_medications:** cantidad de medicamentos.
# * **number_outpatient:** cantidad de consultas con el médico general.
# * **number_emergency:** número de emergencias.
# * **number_inpatient:** tipo de paciente interno
# * **diag_1:**
# * **diag_2:**
# * **diag_3:**
# * **number_diagnoses:** número que indica la intensidad de la diabetes diagnosticada.
# * **readmitted** Cantidad aproximada de las veces que el paciente a sido interno.

# %% [markdown]
# ##  - **Realizar un resumen estadístico de todas las variables**

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
Datos = pd.read_csv("diabetic_data.csv")

# %%
Datos.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# ...

# %%
Datos.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
Datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
# encounter_id                101766 non-null int64
# patient_nbr                 101766 non-null int64
# race                        101766 non-null object
# gender                      101766 non-null object
# age                         101766 non-null object
# weight                      101766 non-null object
# admission_type_id           101766 non-null int64
# discharge_disposition_id    101766 non-null int64
# admission_source_id         101766 non-null int64
# time_in_hospital            101766 non-null int64
# payer_code                  101766 non-null object
# medical_specialty           101766 non-null object
# num_lab_procedures          101766 non-null int64
# num_procedures              101766 non-null int64
# num_medications             101766 non-null int64
# number_outpatient           101766 non-null int64
# ...

# %%
Datos.shape
# Out:
# (101766, 50)

# %% [markdown]
# ## - **Después del resumen determinar 10 variables de interés, describirlas por separado (structure y summarize)**

# %% [markdown]
# ### Cualitativas:
# * **Race:** raza del paciente.
# * **Gender:** genero del paciente.
# * **admission_source_id:** código, tipo de precedencia del paciente.
# * **medical_specialty:** Especialidad médica que el paciente requirió.
#
# ### Cuantitativas:
# * **Age:** rango de edad del paciente.
# * **time_in_hospital:** días de permanencia en el hospital.
# * **num_lab_procedures:** cantidad de laboratorios realizados.
# * **num_medications:** cantidad de medicamentos.
# * **number_outpatient:** cantidad de consultas con el médico general.
# * **readmitted** Cantidad aproximada de las veces que el paciente a sido interno.

# %%
Importantes = Datos[['race', 'gender', 'admission_type_id', 'medical_specialty', 'age', 'time_in_hospital', 'num_lab_procedures', 'num_medications', 'number_outpatient', 'readmitted']]
Importantes.head()
# Out:
#               race  gender  admission_type_id         medical_specialty  \
# 0        Caucasian  Female                  6  Pediatrics-Endocrinology
# 1        Caucasian  Female                  1                         ?
# 2  AfricanAmerican  Female                  1                         ?
# 3        Caucasian    Male                  1                         ?
# 4        Caucasian    Male                  1                         ?
#
#        age  time_in_hospital  num_lab_procedures  num_medications  \
# 0   [0-10)                 1                  41                1
# 1  [10-20)                 3                  59               18
# 2  [20-30)                 2                  11               13
# 3  [30-40)                 2                  44               16
# 4  [40-50)                 1                  51                8
#
#    number_outpatient readmitted
# 0                  0         NO
# 1                  0        >30
# 2                  2         NO
# ...

# %%
Importantes.describe()
# Out:
#        admission_type_id  time_in_hospital  num_lab_procedures  \
# count      101766.000000     101766.000000       101766.000000
# mean            2.024006          4.395987           43.095641
# std             1.445403          2.985108           19.674362
# min             1.000000          1.000000            1.000000
# 25%             1.000000          2.000000           31.000000
# 50%             1.000000          4.000000           44.000000
# 75%             3.000000          6.000000           57.000000
# max             8.000000         14.000000          132.000000
#
#        num_medications  number_outpatient
# count    101766.000000      101766.000000
# mean         16.021844           0.369357
# std           8.127566           1.267265
# min           1.000000           0.000000
# 25%          10.000000           0.000000
# 50%          15.000000           0.000000
# 75%          20.000000           0.000000
# max          81.000000          42.000000

# %% [markdown]
# ##  - **Gráficas**

# %% [markdown]
# ### Histogramas

# %%
plt.hist(Importantes.admission_type_id)
# Out:
# (array([  5.39900000e+04,   1.84800000e+04,   1.88690000e+04,
#           0.00000000e+00,   1.00000000e+01,   4.78500000e+03,
#           0.00000000e+00,   5.29100000e+03,   2.10000000e+01,
#           3.20000000e+02]),
#  array([ 1. ,  1.7,  2.4,  3.1,  3.8,  4.5,  5.2,  5.9,  6.6,  7.3,  8. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(Importantes.time_in_hospital)
# Out:
# (array([ 31432.,  17756.,  13924.,  17505.,   5859.,   4391.,   5344.,
#           1855.,   1448.,   2252.]),
#  array([  1. ,   2.3,   3.6,   4.9,   6.2,   7.5,   8.8,  10.1,  11.4,
#          12.7,  14. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(Importantes.num_lab_procedures, 40)
# Out:
# (array([  5.35500000e+03,   8.91000000e+02,   2.13700000e+03,
#           1.93500000e+03,   1.74800000e+03,   2.47000000e+03,
#           2.20600000e+03,   3.71700000e+03,   3.74200000e+03,
#           3.94400000e+03,   7.62500000e+03,   6.51500000e+03,
#           7.03400000e+03,   7.06100000e+03,   8.15400000e+03,
#           5.56500000e+03,   5.56300000e+03,   5.07900000e+03,
#           6.14200000e+03,   3.77400000e+03,   3.12700000e+03,
#           3.03400000e+03,   1.60300000e+03,   1.11200000e+03,
#           8.01000000e+02,   6.74000000e+02,   2.66000000e+02,
#           1.74000000e+02,   1.47000000e+02,   9.40000000e+01,
#           3.40000000e+01,   1.50000000e+01,   1.40000000e+01,
#           3.00000000e+00,   5.00000000e+00,   1.00000000e+00,
#           2.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           2.00000000e+00]),
#  array([   1.   ,    4.275,    7.55 ,   10.825,   14.1  ,   17.375,
# ...

# %%
plt.hist(Importantes.num_medications, 20)
# Out:
# (array([  3.04900000e+03,   1.25530000e+04,   2.20580000e+04,
#           2.30150000e+04,   1.72110000e+04,   1.06330000e+04,
#           6.16100000e+03,   3.18400000e+03,   1.63200000e+03,
#           9.09000000e+02,   5.01000000e+02,   3.14000000e+02,
#           2.13000000e+02,   1.42000000e+02,   9.40000000e+01,
#           5.10000000e+01,   3.10000000e+01,   1.00000000e+01,
#           3.00000000e+00,   2.00000000e+00]),
#  array([  1.,   5.,   9.,  13.,  17.,  21.,  25.,  29.,  33.,  37.,  41.,
#          45.,  49.,  53.,  57.,  61.,  65.,  69.,  73.,  77.,  81.]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(Importantes.number_outpatient)
# Out:
# (array([  1.00309000e+05,   1.08900000e+03,   2.12000000e+02,
#           9.40000000e+01,   2.30000000e+01,   1.90000000e+01,
#           8.00000000e+00,   2.00000000e+00,   6.00000000e+00,
#           4.00000000e+00]),
#  array([  0. ,   4.2,   8.4,  12.6,  16.8,  21. ,  25.2,  29.4,  33.6,
#          37.8,  42. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Boxplot

# %%
filtro = Importantes.race != '?'
RACE = Importantes[filtro]
sns.boxplot(RACE)
# Out:
# C:\Users\linda\Anaconda2\lib\site-packages\seaborn\categorical.py:2125: UserWarning: The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(Importantes.admission_type_id)

# %%
sns.boxplot(Importantes.time_in_hospital)

# %%
sns.boxplot(Importantes.num_lab_procedures)

# %%
sns.boxplot(Importantes.num_medications)

# %%
sns.boxplot(Importantes.number_outpatient)

# %% [markdown]
# ### Distribución

# %%
sns.kdeplot(Importantes.admission_type_id, cumulative=True)

# %%
sns.kdeplot(Importantes.time_in_hospital, cumulative=True)

# %%
sns.kdeplot(Importantes.num_lab_procedures, cumulative=True)

# %%
sns.kdeplot(Importantes.num_medications, cumulative=True)

# %% [markdown]
# ### Densidad

# %%
sns.kdeplot(Importantes.admission_type_id, shade=True)

# %%
sns.kdeplot(Importantes.time_in_hospital, shade=True)

# %%
sns.kdeplot(Importantes.num_lab_procedures, shade=True)

# %%
sns.kdeplot(Importantes.num_medications, shade=True)

# %%
sns.kdeplot(Importantes.number_outpatient, shade=True)

# %% [markdown]
# ### Violin

# %%
sns.violinplot(Importantes.admission_type_id)

# %%
sns.violinplot(Importantes.time_in_hospital)

# %%
sns.violinplot(Importantes.num_lab_procedures)

# %%
sns.violinplot(Importantes.num_medications)

# %%
sns.violinplot(Importantes.number_outpatient)
